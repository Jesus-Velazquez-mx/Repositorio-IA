# %% [markdown]
# # Extracting Features from Images
# ##### Obtaining pixel intensities for image and transforming those into usable features

# %% [markdown]
# #### Installation of opencv may be required
#
# OpenCV == Open Source Computer Vision Library

# %%
# !pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting opencv-python
#   Downloading opencv_python-4.13.0.92-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=2 in c:\users\jesu1\appdata\roaming\python\python314\site-packages (from opencv-python) (2.4.3)
# Downloading opencv_python-4.13.0.92-cp37-abi3-win_amd64.whl (40.2 MB)
#    ---------------------------------------- 0.0/40.2 MB ? eta -:--:--
#     --------------------------------------- 0.5/40.2 MB 6.7 MB/s eta 0:00:06
#    --- ------------------------------------ 3.9/40.2 MB 15.1 MB/s eta 0:00:03
#    -------- ------------------------------- 8.9/40.2 MB 19.0 MB/s eta 0:00:02
#    -------------- ------------------------- 14.4/40.2 MB 21.6 MB/s eta 0:00:02
#    ------------------- -------------------- 19.4/40.2 MB 22.5 MB/s eta 0:00:01
#    ------------------------ --------------- 24.4/40.2 MB 22.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 29.1/40.2 MB 22.9 MB/s eta 0:00:01
#    --------------------------------- ------ 33.6/40.2 MB 22.8 MB/s eta 0:00:01
#    ------------------------------------- -- 38.0/40.2 MB 22.8 MB/s eta 0:00:01
#    ---------------------------------------- 40.2/40.2 MB 21.9 MB/s  0:00:01
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.13.0.92
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: C:\Python314\python.exe -m pip install --upgrade pip

# %%
import cv2

# %% [markdown]
# #### Load an image from which to extract RGB pixel intensities

# %%
# Image with dimensions 173x130
imagePath = '../data/dog.jpg'

image = cv2.imread(imagePath)

# %% [markdown]
# #### View image using matplotlib

# %%
# %matplotlib inline

import matplotlib
import matplotlib.pyplot as plt

plt.imshow(image)

# %% [markdown]
# #### Image array contains RGB values for each pixel in the image

# %%
image.shape
# Out:
# (130, 173, 3)

# %%
image
# Out:
# array([[[199, 171, 164],
#         [227, 206, 198],
#         [249, 237, 231],
#         ...,
#         [253, 242, 234],
#         [254, 243, 235],
#         [254, 243, 235]],
#
#        [[221, 195, 188],
#         [228, 209, 201],
#         [246, 237, 228],
#         ...,
#         [254, 243, 235],
#         [255, 243, 237],
#         [254, 242, 236]],
#
#        [[227, 209, 198],
#         [225, 210, 201],
#         [238, 231, 222],
#         ...,
#         [254, 242, 236],
#         [254, 242, 238],
#         [253, 241, 237]],
#
#        ...,
#
#        [[203, 207, 208],
#         [199, 203, 204],
#         [200, 202, 203],
#         ...,
#         [ 98, 112, 118],
#         [ 99, 113, 119],
#         [ 98, 112, 118]],
#
#        [[201, 202, 206],
#         [203, 204, 208],
#         [204, 205, 209],
#         ...,
#         [103, 115, 119],
#         [107, 119, 123],
#         [104, 116, 120]],
#
#        [[200, 201, 205],
#         [201, 202, 206],
#         [203, 204, 208],
#         ...,
#         [106, 118, 122],
#         [111, 123, 127],
#         [108, 120, 124]]], shape=(130, 173, 3), dtype=uint8)

# %% [markdown]
# #### Each pixel has RGB intensities

# %%
image[0][0]
# Out:
# array([199, 171, 164], dtype=uint8)

# %% [markdown]
# #### Scale this image to a smaller size

# %%
size=(32, 32)
resized_image_feature_vector = cv2.resize(image, size)

# %%
plt.imshow(resized_image_feature_vector)

# %%
resized_image_feature_vector.shape
# Out:
# (32, 32, 3)

# %%
resized_image_feature_vector
# Out:
# array([[[244, 237, 228],
#         [251, 254, 253],
#         [255, 250, 242],
#         ...,
#         [253, 247, 242],
#         [255, 245, 238],
#         [254, 243, 236]],
#
#        [[126, 118, 108],
#         [237, 218, 211],
#         [166, 156, 144],
#         ...,
#         [255, 246, 242],
#         [255, 245, 241],
#         [254, 241, 233]],
#
#        [[254, 253, 251],
#         [255, 254, 252],
#         [254, 253, 251],
#         ...,
#         [250, 239, 230],
#         [243, 224, 214],
#         [190, 177, 165]],
#
#        ...,
#
#        [[206, 206, 210],
#         [208, 209, 213],
#         [207, 208, 212],
#         ...,
#         [119, 131, 138],
#         [121, 135, 141],
#         [115, 129, 136]],
#
#        [[207, 208, 211],
#         [211, 209, 212],
#         [213, 211, 214],
#         ...,
#         [110, 124, 130],
#         [104, 118, 124],
#         [107, 121, 127]],
#
#        [[202, 204, 206],
#         [211, 210, 213],
#         [211, 209, 211],
#         ...,
#         [119, 132, 137],
#         [100, 113, 118],
#         [ 99, 112, 118]]], shape=(32, 32, 3), dtype=uint8)

# %% [markdown]
# #### Image array can be flattened into a one-dimensional array

# %%
resized_flattened_image_feature_vector = resized_image_feature_vector.flatten()

# %%
len(resized_flattened_image_feature_vector)
# Out:
# 3072

# %%
image_grayscale = cv2.imread(imagePath, cv2.IMREAD_GRAYSCALE )

# %%
plt.imshow(image_grayscale)

# %%
image_grayscale.shape
# Out:
# (130, 173)

# %%
image_grayscale
# Out:
# array([[172, 206, 237, ..., 241, 242, 242],
#        [196, 209, 235, ..., 242, 243, 242],
#        [208, 209, 229, ..., 242, 242, 241],
#        ...,
#        [207, 203, 202, ..., 112, 113, 112],
#        [203, 205, 206, ..., 115, 119, 116],
#        [202, 203, 205, ..., 118, 123, 120]], shape=(130, 173), dtype=uint8)

# %%
import numpy as np

expanded_image_grayscale = np.expand_dims(image_grayscale, axis=2)
expanded_image_grayscale.shape
# Out:
# (130, 173, 1)

# %%
expanded_image_grayscale
# Out:
# array([[[172],
#         [206],
#         [237],
#         ...,
#         [241],
#         [242],
#         [242]],
#
#        [[196],
#         [209],
#         [235],
#         ...,
#         [242],
#         [243],
#         [242]],
#
#        [[208],
#         [209],
#         [229],
#         ...,
#         [242],
#         [242],
#         [241]],
#
#        ...,
#
#        [[207],
#         [203],
#         [202],
#         ...,
#         [112],
#         [113],
#         [112]],
#
#        [[203],
#         [205],
#         [206],
#         ...,
#         [115],
#         [119],
#         [116]],
#
#        [[202],
#         [203],
#         [205],
#         ...,
#         [118],
#         [123],
#         [120]]], shape=(130, 173, 1), dtype=uint8)
