# %% [markdown]
# # SVM Model for Image Classification
# ##### Using SVM to classify MNIST data - a set of images of hand-written digits

# %%
import pandas as pd

# %% [markdown]
# ### MNIST data set:
# Text images of 28x28 pixels represented as flattened array of 784 pixels <br />
# Each pixel is represented by a pixel intensity value from 0-255
#
# <b>Download Link: </b>https://www.kaggle.com/c/3004/download/train.csv

# %%
mnist_data = pd.read_csv("../data/mnist/train.csv")
mnist_data.tail()
# Out:
#        label  pixel0  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  \
# 41995      0       0       0       0       0       0       0       0       0
# 41996      1       0       0       0       0       0       0       0       0
# 41997      7       0       0       0       0       0       0       0       0
# 41998      6       0       0       0       0       0       0       0       0
# 41999      9       0       0       0       0       0       0       0       0
#
#        pixel8  ...  pixel774  pixel775  pixel776  pixel777  pixel778  \
# 41995       0  ...         0         0         0         0         0
# 41996       0  ...         0         0         0         0         0
# 41997       0  ...         0         0         0         0         0
# 41998       0  ...         0         0         0         0         0
# 41999       0  ...         0         0         0         0         0
#
#        pixel779  pixel780  pixel781  pixel782  pixel783
# 41995         0         0         0         0         0
# 41996         0         0         0         0         0
# 41997         0         0         0         0         0
# 41998         0         0         0         0         0
# 41999         0         0         0         0         0
#
# [5 rows x 785 columns]

# %% [markdown]
# #### Preparing our training and test data
# The pixel intensities are divided by 255 so that they're all between 0 and 1

# %%
from sklearn.model_selection import train_test_split

features = mnist_data.columns[1:]
X = mnist_data[features]
Y = mnist_data['label']

X_train, X_test, Y_train, y_test = train_test_split(X/255., Y, test_size=0.1, random_state=0)

# %% [markdown]
# #### Create an SVM classifier model
# * penalty can be L1 or L2
# * dual set to false since we have many more samples than features

# %%
from sklearn.svm import LinearSVC

clf_svm = LinearSVC(penalty="l2", dual=False, tol=1e-5)
clf_svm.fit(X_train, Y_train)
# Out:
# LinearSVC(dual=False, tol=1e-05)

# %% [markdown]
# #### Calculate accuracy of the model against the test set

# %%
from sklearn.metrics import accuracy_score

y_pred_svm = clf_svm.predict(X_test)
acc_svm = accuracy_score(y_test, y_pred_svm)
print ('SVM accuracy: ',acc_svm)
# Out:
# SVM accuracy:  0.9102380952380953

# %% [markdown]
# ### Grid Search
# - A brute-force way to obtain the best parameters for the ML algorithm
# - Tries out all combinations of parameters specified in the "grid"
# - Returns combination of parameters with the highest accuracy score
# - Since it explores all combinations - this will take a long time

# %%
from sklearn.model_selection import GridSearchCV

penalties = ['l1', 'l2']
tolerances = [1e-3, 1e-4, 1e-5]

param_grid = {'penalty': penalties, 'tol': tolerances}

grid_search = GridSearchCV(LinearSVC(dual=False), param_grid, cv=3)
grid_search.fit(X_train, Y_train)

grid_search.best_params_
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 9
#       6 param_grid = {'penalty': penalties, 'tol': tolerances}
#       8 grid_search = GridSearchCV(LinearSVC(dual=False), param_grid, cv=3)
# ----> 9 grid_search.fit(X_train, Y_train)
#      11 grid_search.best_params_
#
# File c:\Users\jesu1\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\jesu1\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\model_selection\_search.py:1053, in BaseSearchCV.fit(self, X, y, **params)
#    1047     results = self._format_results(
#    1048         all_candidate_params, n_splits, all_out, all_more_results
#    1049     )
#    1051     return results
# -> 1053 self._run_search(evaluate_candidates)
#    1055 # multimetric is determined here because in the case of a callable
#    1056 # self.scoring the return type is only known after calling
#    1057 first_test_score = all_out[0]["test_scores"]
#
# File c:\Users\jesu1\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\model_selection\_search.py:1612, in GridSearchCV._run_search(self, evaluate_candidates)
#    1610 def _run_search(self, evaluate_candidates):
#    1611     """Search all candidates in param_grid"""
# -> 1612     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File c:\Users\jesu1\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\model_selection\_search.py:999, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     991 if self.verbose > 0:
#     992     print(
#     993         "Fitting {0} folds for each of {1} candidates,"
#     994         " totalling {2} fits".format(
#     995             n_splits, n_candidates, n_candidates * n_splits
#     996         )
#     997     )
# --> 999 out = parallel(
#    1000     delayed(_fit_and_score)(
#    1001         clone(base_estimator),
#    1002         X,
#    1003         y,
#    1004         train=train,
#    1005         test=test,
#    1006         parameters=parameters,
#    1007         split_progress=(split_idx, n_splits),
#    1008         candidate_progress=(cand_idx, n_candidates),
#    1009         **fit_and_score_kwargs,
#    1010     )
#    1011     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#    1012         enumerate(candidate_params),
#    1013         enumerate(cv.split(X, y, **routed_params.splitter.split)),
#    1014     )
#    1015 )
#    1017 if len(out) < 1:
#    1018     raise ValueError(
#    1019         "No fits were performed. "
#    1020         "Was the CV iterator empty? "
#    1021         "Were there no candidates?"
#    1022     )
#
# File c:\Users\jesu1\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\utils\parallel.py:91, in Parallel.__call__(self, iterable)
#      79 warning_filters = (
#      80     filters_func() if filters_func is not None else warnings.filters
#      81 )
#      83 iterable_with_config_and_warning_filters = (
#      84     (
#      85         _with_config_and_warning_filters(delayed_func, config, warning_filters),
#    (...)     89     for delayed_func, args, kwargs in iterable
#      90 )
# ---> 91 return super().__call__(iterable_with_config_and_warning_filters)
#
# File c:\Users\jesu1\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\joblib\parallel.py:1986, in Parallel.__call__(self, iterable)
#    1984     output = self._get_sequential_output(iterable)
#    1985     next(output)
# -> 1986     return output if self.return_generator else list(output)
#    1988 # Let's create an ID that uniquely identifies the current call. If the
#    1989 # call is interrupted early and that the same instance is immediately
#    1990 # reused, this id will be used to prevent workers that were
#    1991 # concurrently finalizing a task from the previous call to run the
#    1992 # callback.
#    1993 with self._lock:
#
# File c:\Users\jesu1\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\joblib\parallel.py:1914, in Parallel._get_sequential_output(self, iterable)
#    1912 self.n_dispatched_batches += 1
#    1913 self.n_dispatched_tasks += 1
# -> 1914 res = func(*args, **kwargs)
#    1915 self.n_completed_tasks += 1
#    1916 self.print_progress()
#
# File c:\Users\jesu1\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\utils\parallel.py:184, in _FuncWrapper.__call__(self, *args, **kwargs)
#     180                 this_warning_filter_dict[special_key] = this_value.pattern
#     182         warnings.filterwarnings(**this_warning_filter_dict, append=True)
# --> 184 return self.function(*args, **kwargs)
#
# File c:\Users\jesu1\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\model_selection\_validation.py:833, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, score_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     831         estimator.fit(X_train, **fit_params)
#     832     else:
# --> 833         estimator.fit(X_train, y_train, **fit_params)
#     835 except Exception:
#     836     # Note fit time as time until error
#     837     fit_time = time.time() - start_time
#
# File c:\Users\jesu1\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\jesu1\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\svm\_classes.py:330, in LinearSVC.fit(self, X, y, sample_weight)
#     324 self.classes_ = np.unique(y)
#     326 _dual = _validate_dual_parameter(
#     327     self.dual, self.loss, self.penalty, self.multi_class, X
#     328 )
# --> 330 self.coef_, self.intercept_, n_iter_ = _fit_liblinear(
#     331     X,
#     332     y,
#     333     self.C,
#     334     self.fit_intercept,
#     335     self.intercept_scaling,
#     336     self.class_weight,
#     337     self.penalty,
#     338     _dual,
#     339     self.verbose,
#     340     self.max_iter,
#     341     self.tol,
#     342     self.random_state,
#     343     self.multi_class,
#     344     self.loss,
#     345     sample_weight=sample_weight,
#     346 )
#     347 # Backward compatibility: _fit_liblinear is used both by LinearSVC/R
#     348 # and LogisticRegression but LogisticRegression sets a structured
#     349 # `n_iter_` attribute with information about the underlying OvR fits
#     350 # while LinearSVC/R only reports the maximum value.
#     351 self.n_iter_ = n_iter_.max().item()
#
# File c:\Users\jesu1\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\svm\_base.py:1238, in _fit_liblinear(X, y, C, fit_intercept, intercept_scaling, class_weight, penalty, dual, verbose, max_iter, tol, random_state, multi_class, loss, epsilon, sample_weight)
#    1235 sample_weight = _check_sample_weight(sample_weight, X, dtype=np.float64)
#    1237 solver_type = _get_liblinear_solver_type(multi_class, penalty, loss, dual)
# -> 1238 raw_coef_, n_iter_ = liblinear.train_wrap(
#    1239     X,
#    1240     y_ind,
#    1241     sp.issparse(X),
#    1242     solver_type,
#    1243     tol,
#    1244     bias,
#    1245     C,
#    1246     class_weight_,
#    1247     max_iter,
#    1248     rnd.randint(np.iinfo("i").max),
#    1249     epsilon,
#    1250     sample_weight,
#    1251 )
#    1252 # Regarding rnd.randint(..) in the above signature:
#    1253 # seed for srand in range [0..INT_MAX); due to limitations in Numpy
#    1254 # on 32-bit platforms, we can't get to the UINT_MAX limit that
#    1255 # srand supports
#    1256 n_iter_max = max(n_iter_)
#
# KeyboardInterrupt:

# %% [markdown]
# #### Plugging in the "best parameters" to redefine the model

# %%
clf_svm = LinearSVC(penalty="l1", dual=False, tol=1e-3)
clf_svm.fit(X_train, Y_train)
# Out:
# LinearSVC(dual=False, penalty='l1', tol=0.001)

# %%
y_pred_svm = clf_svm.predict(X_test)
acc_svm = accuracy_score(y_test, y_pred_svm)
print ('SVM accuracy: ',acc_svm)
# Out:
# SVM accuracy:  0.9116666666666666
